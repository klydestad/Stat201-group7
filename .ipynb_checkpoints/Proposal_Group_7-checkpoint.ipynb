# %%
### Run this cell before continuing.
#library(cowplot)
library(dplyr)
library(gridExtra)
library(tidyverse)
library(repr)
library(infer)
library(repr)
library(datateachr)
library(digest)
library(lubridate)
library(taxyvr)
library(broom)
library(testthat)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0     ✔ purrr   1.0.0
# ✔ tibble  3.1.8     ✔ stringr 1.5.0
# ✔ tidyr   1.2.1     ✔ forcats 0.5.2
# ✔ readr   2.1.3
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ gridExtra::combine() masks dplyr::combine()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ dplyr::lag()         masks stats::lag()
# Error in library(infer): there is no package called ‘infer’
# Traceback:
#
# 1. library(infer)

# %% [markdown]
# *STAT 201 - GROUP 7*

# %% [markdown]
# # Comparing Car Theft in Vancouver, BC. (rough title)

# %% [markdown]
# Analysis by Soham Chakote, Lisa Desjarlais, Kiersten Lyde-Stad, Hongli Zhang

# %% [markdown]
# # Introduction

# %% [markdown]
# ### Background

# %% [markdown]
# ### Question

# %% [markdown]
# "Concerning 2018 to 2022, is the proportion of thefts from vehicles in the Strathcona and Grandview-Woodland districts significantly higher than in the West End and Central Business districts of Vancouver, BC.?"

# %% [markdown]
# # Preliminary Results

# %% [markdown]
# ##### Read, Clean, & Wrangle

# %%
#Read and Combine CSVS (code from https://statisticsglobe.com/merge-csv-files-in-r)
crime <- list.files(path = "data/", 
                       pattern = "*.csv", full.names = TRUE) %>% 
  lapply(read_csv, show_col_types=FALSE) %>%      #Quieted messages                      
  bind_rows      
head(crime)
# Out:
#   TYPE               YEAR MONTH DAY HOUR MINUTE HUNDRED_BLOCK
# 1 Theft from Vehicle 2018  8    27  15   30     1X E CORDOVA ST
# 2 Theft from Vehicle 2018 11    27  17    0     1X W HASTINGS ST
# 3 Theft from Vehicle 2018  2     3  23    0     1XX ABBOTT ST
# 4 Theft from Vehicle 2018  7    23  14    0     1XX ABBOTT ST
# 5 Theft from Vehicle 2018  1     8  23   48     1XX ABBOTT ST
# 6 Theft from Vehicle 2018  1    19  23    0     1XX ABBOTT ST
#   NEIGHBOURHOOD             X        Y
# 1 Central Business District 492441.8 5458858
# 2 Central Business District 492375.3 5458758
# 3 Central Business District 492271.3 5459048
# 4 Central Business District 492271.3 5459048
# 5 Central Business District 492274.3 5459062
# 6 Central Business District 492274.3 5459062

# %% [markdown]
# ##### Plot(s)

# %%
crime2s <- crime |>
    select(TYPE, YEAR, NEIGHBOURHOOD)
crime_theft_prop <- crime2s |>
    group_by(NEIGHBOURHOOD) |>
    summarize(n_all_crime = n(),
              n_thefts = sum(TYPE == "Theft from Vehicle"),
              prop = n_thefts / n_all_crime)
crime_theft_prop
              
crime_theft_ave <- crime2s |>
    filter(TYPE == "Theft from Vehicle") |>
    group_by(NEIGHBOURHOOD) |>
    summarize(n = n(),
              mean_theft = n / 4)
crime_theft_ave
# Out:
#   NEIGHBOURHOOD             n_all_crime n_thefts prop
# 1 Central Business District 60377       18899    0.3130165
# 2 Grandview-Woodland         9583        2451    0.2557654
# 3 Strathcona                14576        3304    0.2266740
# 4 West End                  16932        5341    0.3154382
#   NEIGHBOURHOOD             n     mean_theft
# 1 Central Business District 18899 4724.75
# 2 Grandview-Woodland         2451  612.75
# 3 Strathcona                 3304  826.00
# 4 West End                   5341 1335.25

# %%
prop_theft_plot <- crime_theft_prop |>
    ggplot(aes(x = NEIGHBOURHOOD, y = prop, fill = NEIGHBOURHOOD)) +
    geom_bar(stat = "identity") +
    labs(title = "Proportion of Vehicle Thefts", x = "District", y = "Theft Proportions") +
    theme(text = element_text(size = 15), axis.text.x = element_text(angle = 45,hjust=1))
prop_theft_plot
# Out:
# plot without title

# %%
mean_theft_plot <- crime_theft_ave |>
    ggplot(aes(x = NEIGHBOURHOOD, y = mean_theft, fill = NEIGHBOURHOOD)) +
    geom_bar(stat = "identity") +
    labs(title = "Average Number of Vehicle Thefts", x = "District", y = "Average Thefts") +
    theme(text = element_text(size = 15), axis.text.x = element_text(angle = 45,hjust=1))

mean_theft_plot
# Out:
# plot without title

# %%
all_thefts_plot <- crime2s |>
    filter(TYPE == "Theft from Vehicle") |>
    group_by(NEIGHBOURHOOD) |>
    summarize(n = n()) |>
    ggplot(aes(x = NEIGHBOURHOOD, y = n, fill = NEIGHBOURHOOD)) +
    geom_bar(stat = "identity") +
    labs(title = "Total Number of Vehicle Thefts", x = "District", y = "Number of Thefts") +
    theme(text = element_text(size = 15), axis.text.x = element_text(angle = 45,hjust=1))
    
all_thefts_plot
# Out:
# plot without title

# %% [markdown]
# ##### Table of Estimates

# %% [markdown]
# # Methods: Plan

# %% [markdown]
# (The previous sections will carry over to your final report (you’ll be allowed to improve them based on feedback you get). Begin this Methods section with a brief description of “the good things” about this report – specifically, in what ways is this report trustworthy?
#
# Continue by explaining why the plot(s) and estimates that you produced are not enough to give to a stakeholder, and what you should provide in addition to address this gap. Make sure your plans include at least one hypothesis test and one confidence interval. If possible, compare both the bootstrapping and asymptotics methods.)

# %% [markdown]
# ##### What do you expect to find?

# %% [markdown]
# We expect to find that areas locally known as "nicer" areas will have lower numbers of vehicle thefts, such as the Eest End, compared to neighbourhoods such as Strathcona. We also expect that the results given by numbers will differ from the results given by proportions, as neighbourhoods are not all equal in size, population, wealth, and other factors that can impact vehicle theft rates.

# %% [markdown]
#  ##### What impact could such findings have?

# %% [markdown]
# Car security is an important

# %% [markdown]
# ##### What future questions could this lead to?

# %% [markdown]
# # References

# %% [markdown]
# At least two citations of literature relevant to the project. The citation format is your choice – just be consistent. Make sure to cite the source of your data as well.

# %% [markdown]
# - 1
# - 2
